# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import scipy.constants as const
from matplotlib.ticker import (MultipleLocator, FormatStrFormatter,
                               AutoMinorLocator, ScalarFormatter)
from matplotlib.colors import LogNorm
from scipy import interpolate
from scipy import constants as scp
from scipy.integrate import quad
from scipy.integrate import simps
from scipy.special import kv, airy, gamma
from scipy.optimize import curve_fit
#
from scipy import integrate as int_scp
from mpl_toolkits.axes_grid1.inset_locator import zoomed_inset_axes, mark_inset
import pandas as pd
import os
from glob import glob
import cv2
#
from tqdm import trange, tqdm_notebook
from scipy.signal import find_peaks
from scipy.signal import savgol_filter

# %%
import uproot

# %%
SMALL_SIZE = 16
MEDIUM_SIZE = 18
BIGGER_SIZE = 22

plt.rc('font', size=SMALL_SIZE)          # controls default text sizes
plt.rc('axes', titlesize=SMALL_SIZE)     # fontsize of the axes title
plt.rc('axes', labelsize=MEDIUM_SIZE)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
plt.rc('ytick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
plt.rc('legend', fontsize=16)    # legend fontsize
plt.rc('figure', titlesize=BIGGER_SIZE)  # fontsize of the figure title

ml = MultipleLocator(2)

# %%
# Define the Gaussian function
def gaussian(x, A, x0, sigma, c):
    return A * np.exp(-(x - x0)**2 / (2 * sigma**2)) + c

# %% [markdown]
# ## Simulation Parameters
#
# PP with a large hole 25 um, 200 um thickness, 0 deg rotation, 50 x 50 holes.
#
# **Sims parameters**
#
# * PP simulation: 23.25 um and 1.85 mrad
# * Laser grating: 2.45 um and 2.65 mrad
# * Mean energy: 72 MeV

# %%
file = uproot.open("../build-PP_complete/Emittance_PP_experiment_params_72MeV_23.25um_1.85mrad(2).root")
file = uproot.open("../build-PP_complete_4deg/Emittance_PP_experiment_params_72MeV_23.25um_1.85mrad_4deg.root")
file = uproot.open("../build-PP_complete_10deg/Emittance_PP_experiment_params_72MeV_23.25um_1.85mrad_10deg.root")
# Emittance_PP_experiment_100MeV_5e6Events
# Emittance_PP_experiment_72MeV_5e6Events
# Emittance_PP_experiment_500MeV_5e6Events.root

# %%
## Read data from Ntuple
key_id = 'Electrons_Screen;1'
ypos_tuple = file[key_id]['ypos'].array(library="np")
zpos_tuple = file[key_id]['zpos'].array(library="np")
xpos_tuple = file[key_id]['xpos'].array(library="np")

px_tuple = file[key_id]['px'].array(library="np")
py_tuple = file[key_id]['py'].array(library="np")
pz_tuple = file[key_id]['pz'].array(library="np")
#

# %% [markdown]
# ## Electron hits on the screen

# %%
# hits at screen
scale_pos = 10 # mm
binsx = np.linspace(-scale_pos, scale_pos, 400)
binsy = np.linspace(-scale_pos, scale_pos, 400)
#
hist_position, yedges, zedges = np.histogram2d(ypos_tuple, zpos_tuple, bins=(binsx, binsy))
yedges_center = yedges[:-1] + (yedges[1] - yedges[2])/2
zedges_center = zedges[:-1] + (zedges[1] - zedges[2])/2

XX, YY = np.meshgrid(yedges_center, zedges_center)

# %%
plt.pcolormesh(XX, YY, hist_position)
plt.show()

# %% [markdown]
# ## Divergence of electrons at screen

# %%
# Divergence calculation
z_div_mrad = np.arctan(pz_tuple/px_tuple) * 1e3
y_div_mrad = np.arctan(py_tuple/px_tuple) * 1e3

# %%
# divergence at screen
scale_theta = 10 # mm
binsx_theta = np.linspace(-scale_theta, scale_theta, 400)
binsy_theta = np.linspace(-scale_theta, scale_theta, 400)
#
hist_theta, yedges_theta, zedges_theta = np.histogram2d(y_div_mrad, z_div_mrad, bins=(binsx_theta, binsy_theta))
yedges_theta_center = yedges_theta[:-1] + (yedges_theta[1] - yedges_theta[2])/2
zedges_theta_center = zedges_theta[:-1] + (zedges_theta[1] - zedges_theta[2])/2

XX_theta, YY_theta = np.meshgrid(yedges_theta_center, zedges_theta_center)

# %%
plt.pcolormesh(XX_theta, YY_theta, hist_theta)
plt.show()

# %% [markdown]
# ## Vertical and Horizontal integrations

# %%
## vertical integration
theta_vert_int = np.sum(hist_theta, axis = 0)

# %%
## Horizontal integration
theta_horz_int = np.sum(hist_theta, axis = 1)

# %% [markdown]
# ## Plot the results

# %%
fig, axes1 = plt.subplots(2,2, figsize=(10, 8))
axes = iter(np.ravel(axes1))

###########################################
ax = next(axes)
ax.pcolormesh(XX, YY, hist_position, cmap='viridis')
ax.set_title('Hits at Screen')
ax.set_xlabel('y- mm')
ax.set_ylabel('z- mm')
ax.set_xlim(-10, 10)
ax.set_ylim(-10, 10)

###########################################
ax = next(axes)
ax.pcolormesh(XX_theta, YY_theta, hist_theta, cmap='viridis')
ax.set_xlim(-10, 10)
ax.set_ylim(-10, 10)
ax.set_title('Divergence at the screen')
ax.set_xlabel('y- mrad')
ax.set_ylabel('z- mrad')

###########################################
ax = next(axes)
ax.plot(yedges_theta_center, theta_vert_int, label='GEANT4\nIntegration', color='black', lw=1.3)

#ax.plot(yedges_theta_center*1e3, data_fit_y, label='Gaussian fit', color='red', lw=2 , linestyle='dashed')


text_legend2 = ("$\sigma_y$ = %.1f \u03BCrad\n" + 
                "$2\sigma_y$ = %.1f \u03BCrad\n"+
                "FWHM$_y$ = %.1f \u03BCrad\n")%(popt_y[2]*1e3, 
                                                2*popt_y[2]*1e3, 
                                                2.35*popt_y[2]*1e3)

#_=ax.text(0.005, 0.85, text_legend2, horizontalalignment='left', color='black', fontsize=10, weight='normal',
#          verticalalignment='center', transform=ax.transAxes)

ax.set_xlim(-10, 10)
#ax.set_ylim(-450, 450)
ax.set_title('$\\theta_y$ at the screen')
ax.set_xlabel('mrad')
ax.set_ylabel('Counts')

ax.legend(loc='upper left', fontsize=11, framealpha=0.95, facecolor='white')


###########################################
ax = next(axes)
ax.plot(zedges_theta_center, theta_horz_int, label='GEANT4\nIntegration', color='black', lw=1.3)

#ax.plot(zedges_theta_center*1e3, data_fit_z, label='Gaussian fit', color='red', lw=2 , linestyle='dashed')


text_legendz = ("$\sigma_z$ = %.1f \u03BCrad\n" + 
                "$2\sigma_z$ = %.1f \u03BCrad\n"+
                "FWHM$_z$ = %.1f \u03BCrad\n")%(popt_z[2]*1e3, 
                                                2*popt_z[2]*1e3, 
                                                2.35*popt_z[2]*1e3)

#_=ax.text(0.005, 0.85, text_legendz, horizontalalignment='left', color='black', fontsize=10, weight='normal',
#          verticalalignment='center', transform=ax.transAxes)

ax.set_xlim(-10, 10)
#ax.set_ylim(-450, 450)
ax.set_title('$\\theta_z$ at the screen')
ax.set_xlabel('mrad')
ax.set_ylabel('Counts')

ax.legend(loc='upper left', fontsize=11, framealpha=0.95, facecolor='white')


plt.tight_layout()

fig.savefig('PP_50um_G4_23.25um_1.85mrad_10deg.png', dpi=450, facecolor='white', format='png', bbox_inches='tight')
plt.show()

# %% [markdown]
# ## Save the results

# %%
x_dir = [zedges_theta_center, theta_horz_int]
np.savetxt('hits_x_direction_PP_10deg.txt', x_dir, fmt='%.9e', delimiter=' ')

# %%
y_dir = [yedges_theta_center, theta_vert_int]
np.savetxt('hits_y_direction_PP_10deg.txt', y_dir, fmt='%.9e', delimiter=' ')

# %% [markdown]
# ## Phase space at the screen

# %%
# divergence at screen
scale_theta_phase = 100 # mm
scale_pos_phase = 100

binsx_theta_phase = np.linspace(-scale_theta_phase, scale_theta_phase, 400)
binsy_pos_phase = np.linspace(-scale_pos_phase, scale_pos_phase, 400)
#
hist_phase, yedges_phase, zedges_phase = np.histogram2d(z_div_mrad, zpos_tuple, bins=(binsx_theta_phase, binsy_pos_phase))
yedges_center = yedges_phase[:-1] + (yedges_phase[1] - yedges_phase[2])/2
zedges_center = zedges_phase[:-1] + (zedges_phase[1] - zedges_phase[2])/2

XX_phase, YY_phase = np.meshgrid(yedges_center, zedges_center)

# %%
## phase space
#scale = 20
binsx = np.linspace(-scale, scale, 200)
binsy = np.linspace(-scale/2, scale/2, 200)

plt.pcolormesh(XX_phase, YY_phase, hist_phase, norm=LogNorm())
plt.colorbar()

#plt.xlim(-scale, scale)
#plt.ylim(-scale/2, scale/2)
plt.xlabel("z mm")
plt.ylabel("$\\theta_z$ mrad")
plt.title('Divergence')
plt.show()
